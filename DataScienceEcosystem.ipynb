# %% [markdown]
# # Data Science Tolls and Ecosystems

# %% [markdown]
# In this notebook, we summarize the main tools, languages, and libraries used in Data Science. We also provide simple examples of arithmetic expressions and basic Python code execution.

# %% [markdown]
# ## Data Science Languages
# - Python
# - R
# - SQL
# - Julia

# %% [markdown]
# ## Data Science Libraries
# - NumPy
# - Pandas
# - Scikit-learn
# - Matplotlib
# - TensorFlow

# %% [markdown]
# ## Data Science Tools
#
# | Tool | Description |
# |------|-------------|
# | Jupyter Notebook | Interactive environment for code and documentation |
# | RStudio | IDE for R programming |
# | Apache Spark | Big data processing engine |

# %% [markdown]
# ## Examples of Arithmetic Expressions
# Below are simple arithmetic expressions:
#
# - `3 + 5` → addition
# - `4 * 7` → multiplication
# - `(10 / 2) + 3` → mixed operations

# %% [markdown]
# # Multiply and add numbers
# result = (5 * 4) + 10
# result

# %% [markdown]
# # Convert minutes to hours
# minutes = 200
# hours = minutes / 60
# hours

# %% [markdown]
# ## Objectives
# - List popular Data Science languages
# - Identify key Data Science libraries
# - Present Data Science tools in a table
# - Demonstrate simple arithmetic expressions

# %% [markdown]
# ## Author
# **Awa Faye**
